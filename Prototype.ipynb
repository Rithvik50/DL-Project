# %% [markdown]
# <a href="https://colab.research.google.com/github/Rithvik50/DL-Project/blob/main/Prototype.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qU langchain-community langchain-text-splitters langchain-huggingface

# %%
# !pip install -qU chromadb

# %%
import os
import re
from typing import List, Dict
from langchain.schema import Document
from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings

class NutritionalDataProcessor:
    def __init__(self, data_dir: str = ".", collection_name: str = "nutrition_data"):
        """
        Initialize the processor with a data directory and collection name
        """
        self.data_dir = data_dir
        self.collection_name = collection_name
        self.text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=1000,
            chunk_overlap=200,
            length_function=len
        )
        self.embedding_function = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

    def load_data_from_directory(self) -> List[str]:
        """
        Load all text files from the specified directory
        """
        text_data = []
        for filename in os.listdir(self.data_dir):
            if filename.endswith('.txt') or filename.endswith('.md'):
                with open(os.path.join(self.data_dir, filename), 'r', encoding='utf-8') as file:
                    text_data.append(f"\n\n=== FILE: {filename} ===\n{file.read()}")
        print(f"Loaded {len(text_data)} files from {self.data_dir}")
        return text_data

    def _split_into_sections(self, text: str) -> Dict[str, str]:
        """
        Split text into sections based on predefined patterns
        """
        sections = {}
        section_patterns = [
            (r"Dietary Reference Intakes for Minerals", "DRI_Minerals"),
            (r"Dietary Reference Intakes for Vitamins and Macronutrients", "DRI_Vitamins_Macros"),
            (r"Estimated Average Requirements \(EAR\)", "EAR"),
            (r"Tolerable Upper Intake Levels \(TUL\)", "TUL")
        ]
        current_section = "Introduction"
        current_content = []
        lines = text.split('\n')
        for line in lines:
            section_found = False
            for pattern, section_name in section_patterns:
                if re.search(pattern, line, re.IGNORECASE):
                    if current_content:
                        sections[current_section] = '\n'.join(current_content)
                    current_section = section_name
                    current_content = [line]
                    section_found = True
                    break
            if not section_found:
                current_content.append(line)
        if current_content:
            sections[current_section] = '\n'.join(current_content)
        print(f"Detected sections: {list(sections.keys())}")
        return sections

    def _is_demographic_group(self, line: str) -> bool:
        """
        Check if a line represents a demographic group header
        """
        demographic_pattern = r"^(?:#+\s+)?(?:Infants|Children|Males|Females|Pregnancy|Lactation)(?:,)?\s*(?:\d+[-–]\d+(?:\+)?\s*(?:y|mo|Years)|>\s*\d+\s*(?:y|Years))"
        print(f"Checking line: '{line.strip()}', Match: {bool(re.match(demographic_pattern, line.strip(), re.IGNORECASE))}")
        return bool(re.match(demographic_pattern, line.strip(), re.IGNORECASE))

    def _process_dri_section(self, content: str, section_type: str) -> List[Document]:
        """
        Process a DRI section into documents with demographic metadata
        """
        documents = []
        current_group = None
        current_nutrients = []
        seen_groups = set()  # Track processed groups to avoid duplicates
        lines = content.split('\n')
        for line in lines:
            line = line.strip()
            if not line:
                continue
            if self._is_demographic_group(line):
                if current_group and current_nutrients and current_group not in seen_groups:
                    doc = self._create_demographic_document(current_group, current_nutrients, section_type)
                    documents.append(doc)
                    seen_groups.add(current_group)
                    print(f"Created document for group: {current_group}, Section: {section_type}")
                current_group = line.strip().lstrip('#').strip()
                current_nutrients = []
            elif ':' in line and any(unit in line for unit in ['mg/d', 'μg/d', 'µg/d', 'g/d', 'L/d']):
                print(f"Parsed nutrient line: {line}")
                current_nutrients.append(line)
        if current_group and current_nutrients and current_group not in seen_groups:
            doc = self._create_demographic_document(current_group, current_nutrients, section_type)
            documents.append(doc)
            seen_groups.add(current_group)
            print(f"Created document for group: {current_group}, Section: {section_type}")
        return documents

    def _extract_metadata(self, group: str, section_type: str, nutrients: List[str]) -> Dict:
        """
        Extract metadata for a document
        """
        nutrient_count = len([n for n in nutrients if ':' in n])
        return {
            "demographic_group": group,
            "section_type": section_type,
            "nutrient_count": nutrient_count,
            "document_type": "general"
        }

    def _create_demographic_document(self, group: str, nutrients: List[str], section_type: str) -> Document:
        """
        Create a LangChain Document for a demographic group
        """
        content = f"Demographic Group: {group}\n"
        content += f"Reference Type: {section_type}\n\n"
        content += "Nutritional Requirements:\n"
        for nutrient in nutrients:
            content += f"- {nutrient}\n"
        metadata = self._extract_metadata(group, section_type, nutrients)
        return Document(page_content=content, metadata=metadata)

    def parse_nutritional_data(self, texts: List[str]) -> List[Document]:
        """
        Parse nutritional data into documents
        """
        all_documents = []
        for text in texts:
            sections = self._split_into_sections(text)
            for section_name, content in sections.items():
                if section_name in ["DRI_Minerals", "DRI_Vitamins_Macros", "EAR", "TUL"]:
                    documents = self._process_dri_section(content, section_name)
                    all_documents.extend(documents)
                else:
                    chunks = self.text_splitter.split_text(content)
                    for i, chunk in enumerate(chunks):
                        metadata = {
                            "section": section_name,
                            "chunk_id": i,
                            "document_type": "general"
                        }
                        all_documents.append(Document(page_content=chunk, metadata=metadata))
        print(f"Created {len(all_documents)} documents")
        return all_documents

    def create_vectorstore(self, documents: List[Document], collection_name: str = None) -> Chroma:
        """
        Create a Chroma vector store from documents
        """
        collection_name = collection_name or self.collection_name
        vectorstore = Chroma.from_documents(
            documents=documents,
            embedding=self.embedding_function,
            collection_name=collection_name,
        )
        print(f"Created vector store with {len(documents)} documents in collection '{collection_name}'")
        return vectorstore

# %%
processor = NutritionalDataProcessor(data_dir=".")
text_data = processor.load_data_from_directory()
documents = processor.parse_nutritional_data(text_data)
vectorstore = processor.create_vectorstore(documents, collection_name="nutrition_data")
# Out:
# /tmp/ipython-input-13-1454532418.py:21: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   self.embedding_function = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Loaded 1 files from .
# Detected sections: ['Introduction', 'DRI_Minerals', 'DRI_Vitamins_Macros', 'EAR', 'TUL']
# Checking line: '# Dietary Reference Intakes for Minerals', Match: False
# Checking line: '## Infants 0-6 months', Match: True
# Checking line: '- **Calcium**: 200 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 200 mg/d
# Checking line: '- **Chromium**: 0.2 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 0.2 μg/d
# Checking line: '- **Copper**: 200 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 200 μg/d
# Checking line: '- **Fluoride**: 0.01 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 0.01 mg/d
# Checking line: '- **Iodine**: 110 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 110 μg/d
# Checking line: '- **Iron**: 0.27 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 0.27 mg/d
# Checking line: '- **Magnesium**: 30 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 30 mg/d
# Checking line: '- **Manganese**: 0.003 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 0.003 mg/d
# Checking line: '- **Molybdenum**: 2 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 2 μg/d
# Checking line: '- **Phosphorus**: 100 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 100 mg/d
# Checking line: '- **Selenium**: 15 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 15 μg/d
# Checking line: '- **Zinc**: 2 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 2 mg/d
# Checking line: '- **Potassium**: 400 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 400 mg/d
# Checking line: '- **Sodium**: 110 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 110 mg/d
# Checking line: '- **Chloride**: 0.18 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 0.18 g/d
# Checking line: '## Infants 7-12 months', Match: True
# Created document for group: Infants 0-6 months, Section: DRI_Minerals
# Checking line: '- **Calcium**: 260 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 260 mg/d
# Checking line: '- **Chromium**: 5.5 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 5.5 μg/d
# Checking line: '- **Copper**: 220 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 220 μg/d
# Checking line: '- **Fluoride**: 0.5 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 0.5 mg/d
# Checking line: '- **Iodine**: 130 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 130 μg/d
# Checking line: '- **Iron**: 11 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 11 mg/d
# Checking line: '- **Magnesium**: 75 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 75 mg/d
# Checking line: '- **Manganese**: 0.6 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 0.6 mg/d
# Checking line: '- **Molybdenum**: 3 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 3 μg/d
# Checking line: '- **Phosphorus**: 275 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 275 mg/d
# Checking line: '- **Selenium**: 20 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 20 μg/d
# Checking line: '- **Zinc**: 3 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 3 mg/d
# Checking line: '- **Potassium**: 860 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 860 mg/d
# Checking line: '- **Sodium**: 370 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 370 mg/d
# Checking line: '- **Chloride**: 0.57 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 0.57 g/d
# Checking line: '## Children 1-3 years', Match: True
# Created document for group: Infants 7-12 months, Section: DRI_Minerals
# Checking line: '- **Calcium**: 700 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 700 mg/d
# Checking line: '- **Chromium**: 11 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 11 μg/d
# Checking line: '- **Copper**: 340 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 340 μg/d
# Checking line: '- **Fluoride**: 0.7 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 0.7 mg/d
# Checking line: '- **Iodine**: 90 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 90 μg/d
# Checking line: '- **Iron**: 7 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 7 mg/d
# Checking line: '- **Magnesium**: 80 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 80 mg/d
# Checking line: '- **Manganese**: 1.2 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 1.2 mg/d
# Checking line: '- **Molybdenum**: 17 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 17 μg/d
# Checking line: '- **Phosphorus**: 460 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 460 mg/d
# Checking line: '- **Selenium**: 20 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 20 μg/d
# Checking line: '- **Zinc**: 3 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 3 mg/d
# Checking line: '- **Potassium**: 2000 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2000 mg/d
# Checking line: '- **Sodium**: 800 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 800 mg/d
# Checking line: '- **Chloride**: 1.5 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 1.5 g/d
# Checking line: '## Children 4-8 years', Match: True
# Created document for group: Children 1-3 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1000 mg/d
# Checking line: '- **Chromium**: 15 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 15 μg/d
# Checking line: '- **Copper**: 440 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 440 μg/d
# Checking line: '- **Fluoride**: 1 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 1 mg/d
# Checking line: '- **Iodine**: 90 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 90 μg/d
# Checking line: '- **Iron**: 10 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 10 mg/d
# Checking line: '- **Magnesium**: 130 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 130 mg/d
# Checking line: '- **Manganese**: 1.5 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 1.5 mg/d
# Checking line: '- **Molybdenum**: 22 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 22 μg/d
# Checking line: '- **Phosphorus**: 500 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 500 mg/d
# Checking line: '- **Selenium** : 30 μg/d', Match: False
# Parsed nutrient line: - **Selenium** : 30 μg/d
# Checking line: '- **Zinc**: 5 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 5 mg/d
# Checking line: '- **Potassium**: 2300 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2300 mg/d
# Checking line: '- **Sodium**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1000 mg/d
# Checking line: '- **Chloride**: 1.9 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 1.9 g/d
# Checking line: '## Males 9-13 years', Match: True
# Created document for group: Children 4-8 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1300 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1300 mg/d
# Checking line: '- **Chromium**: 25 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 25 μg/d
# Checking line: '- **Copper**: 700 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 700 μg/d
# Checking line: '- **Fluoride**: 2 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 2 mg/d
# Checking line: '- **Iodine**: 120 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 120 μg/d
# Checking line: '- **Iron**: 8 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 8 mg/d
# Checking line: '- **Magnesium**: 240 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 240 mg/d
# Checking line: '- **Manganese**: 1.9 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 1.9 mg/d
# Checking line: '- **Molybdenum**: 34 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 34 μg/d
# Checking line: '- **Phosphorus**: 1250 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 1250 mg/d
# Checking line: '- **Selenium**: 40 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 40 μg/d
# Checking line: '- **Zinc**: 8 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 8 mg/d
# Checking line: '- **Potassium**: 2500 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2500 mg/d
# Checking line: '- **Sodium**: 1200 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1200 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '## Males 14-18 years', Match: True
# Created document for group: Males 9-13 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1300 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1300 mg/d
# Checking line: '- **Chromium**: 35 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 35 μg/d
# Checking line: '- **Copper**: 890 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 890 μg/d
# Checking line: '- **Fluoride**: 3 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 3 mg/d
# Checking line: '- **Iodine**: 150 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 150 μg/d
# Checking line: '- **Iron**: 11 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 11 mg/d
# Checking line: '- **Magnesium**: 410 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 410 mg/d
# Checking line: '- **Manganese**: 2.2 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 2.2 mg/d
# Checking line: '- **Molybdenum**: 43 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 43 μg/d
# Checking line: '- **Phosphorus**: 1250 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 1250 mg/d
# Checking line: '- **Selenium**: 55 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 55 μg/d
# Checking line: '- **Zinc**: 11 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 11 mg/d
# Checking line: '- **Potassium**: 3000 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 3000 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '## Males 19-30 years', Match: True
# Created document for group: Males 14-18 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1000 mg/d
# Checking line: '- **Chromium**: 35 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 35 μg/d
# Checking line: '- **Copper**: 900 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 900 μg/d
# Checking line: '- **Fluoride**: 4 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 4 mg/d
# Checking line: '- **Iodine**: 150 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 150 μg/d
# Checking line: '- **Iron**: 8 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 8 mg/d
# Checking line: '- **Magnesium**: 400 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 400 mg/d
# Checking line: '- **Manganese**: 2.3 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 2.3 mg/d
# Checking line: '- **Molybdenum**: 45 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 45 μg/d
# Checking line: '- **Phosphorus**: 700 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 700 mg/d
# Checking line: '- **Selenium**: 55 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 55 μg/d
# Checking line: '- **Zinc**: 11 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 11 mg/d
# Checking line: '- **Potassium**: 3400 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 3400 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '## Males 31-50 years', Match: True
# Created document for group: Males 19-30 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1000 mg/d
# Checking line: '- **Chromium**: 35 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 35 μg/d
# Checking line: '- **Copper**: 900 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 900 μg/d
# Checking line: '- **Fluoride**: 4 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 4 mg/d
# Checking line: '- **Iodine**: 150 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 150 μg/d
# Checking line: '- **Iron**: 8 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 8 mg/d
# Checking line: '- **Magnesium**: 420 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 420 mg/d
# Checking line: '- **Manganese**: 2.3 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 2.3 mg/d
# Checking line: '- **Molybdenum**: 45 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 45 μg/d
# Checking line: '- **Phosphorus**: 700 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 700 mg/d
# Checking line: '- **Selenium**: 55 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 55 μg/d
# Checking line: '- **Zinc**: 11 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 11 mg/d
# Checking line: '- **Potassium**: 3400 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 3400 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '## Males 51-70 years', Match: True
# Created document for group: Males 31-50 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1000 mg/d
# Checking line: '- **Chromium**: 30 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 30 μg/d
# Checking line: '- **Copper**: 900 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 900 μg/d
# Checking line: '- **Fluoride**: 4 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 4 mg/d
# Checking line: '- **Iodine**: 150 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 150 μg/d
# Checking line: '- **Iron**: 8 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 8 mg/d
# Checking line: '- **Magnesium**: 420 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 420 mg/d
# Checking line: '- **Manganese**: 2.3 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 2.3 mg/d
# Checking line: '- **Molybdenum**: 45 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 45 μg/d
# Checking line: '- **Phosphorus**: 700 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 700 mg/d
# Checking line: '- **Selenium**: 55 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 55 μg/d
# Checking line: '- **Zinc**: 11 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 11 mg/d
# Checking line: '- **Potassium**: 3400 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 3400 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2 g/d
# Checking line: '## Males > 70 years', Match: True
# Created document for group: Males 51-70 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1200 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1200 mg/d
# Checking line: '- **Chromium**: 30 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 30 μg/d
# Checking line: '- **Copper**: 900 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 900 μg/d
# Checking line: '- **Fluoride**: 4 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 4 mg/d
# Checking line: '- **Iodine**: 150 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 150 μg/d
# Checking line: '- **Iron**: 8 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 8 mg/d
# Checking line: '- **Magnesium**: 420 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 420 mg/d
# Checking line: '- **Manganese**: 2.3 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 2.3 mg/d
# Checking line: '- **Molybdenum**: 45 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 45 μg/d
# Checking line: '- **Phosphorus**: 700 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 700 mg/d
# Checking line: '- **Selenium**: 55 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 55 μg/d
# Checking line: '- **Zinc**: 11 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 11 mg/d
# Checking line: '- **Potassium**: 3400 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 3400 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 1.8 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 1.8 g/d
# Checking line: '## Females 9-13 years', Match: True
# Created document for group: Males > 70 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1300 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1300 mg/d
# Checking line: '- **Chromium**: 21 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 21 μg/d
# Checking line: '- **Copper**: 700 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 700 μg/d
# Checking line: '- **Fluoride**: 2 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 2 mg/d
# Checking line: '- **Iodine**: 120 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 120 μg/d
# Checking line: '- **Iron**: 8 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 8 mg/d
# Checking line: '- **Magnesium**: 240 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 240 mg/d
# Checking line: '- **Manganese**: 1.6 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 1.6 mg/d
# Checking line: '- **Molybdenum**: 34 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 34 μg/d
# Checking line: '- **Phosphorus**: 1250 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 1250 mg/d
# Checking line: '- **Selenium**: 40 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 40 μg/d
# Checking line: '- **Zinc**: 8 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 8 mg/d
# Checking line: '- **Potassium**: 2300 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2300 mg/d
# Checking line: '- **Sodium**: 1200 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1200 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '## Females 14-18 years', Match: True
# Created document for group: Females 9-13 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1300 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1300 mg/d
# Checking line: '- **Chromium**: 24 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 24 μg/d
# Checking line: '- **Copper**: 890 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 890 μg/d
# Checking line: '- **Fluoride**: 3 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 3 mg/d
# Checking line: '- **Iodine**: 150 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 150 μg/d
# Checking line: '- **Iron**: 15 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 15 mg/d
# Checking line: '- **Magnesium**: 360 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 360 mg/d
# Checking line: '- **Manganese**: 1.6 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 1.6 mg/d
# Checking line: '- **Molybdenum**: 43 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 43 μg/d
# Checking line: '- **Phosphorus**: 1250 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 1250 mg/d
# Checking line: '- **Selenium**: 55 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 55 μg/d
# Checking line: '- **Zinc**: 9 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 9 mg/d
# Checking line: '- **Potassium**: 2300 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2300 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '## Females 19-30 years', Match: True
# Created document for group: Females 14-18 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1000 mg/d
# Checking line: '- **Chromium**: 25 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 25 μg/d
# Checking line: '- **Copper**: 900 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 900 μg/d
# Checking line: '- **Fluoride**: 3 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 3 mg/d
# Checking line: '- **Iodine**: 150 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 150 μg/d
# Checking line: '- **Iron**: 18 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 18 mg/d
# Checking line: '- **Magnesium**: 310 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 310 mg/d
# Checking line: '- **Manganese**: 1.8 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 1.8 mg/d
# Checking line: '- **Molybdenum**: 45 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 45 μg/d
# Checking line: '- **Phosphorus**: 700 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 700 mg/d
# Checking line: '- **Selenium**: 55 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 55 μg/d
# Checking line: '- **Zinc**: 8 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 8 mg/d
# Checking line: '- **Potassium**: 2600 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2600 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '## Females 31-50 years', Match: True
# Created document for group: Females 19-30 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1000 mg/d
# Checking line: '- **Chromium**: 25 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 25 μg/d
# Checking line: '- **Copper**: 900 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 900 μg/d
# Checking line: '- **Fluoride**: 3 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 3 mg/d
# Checking line: '- **Iodine**: 150 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 150 μg/d
# Checking line: '- **Iron**: 18 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 18 mg/d
# Checking line: '- **Magnesium**: 320 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 320 mg/d
# Checking line: '- **Manganese**: 1.8 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 1.8 mg/d
# Checking line: '- **Molybdenum**: 45 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 45 μg/d
# Checking line: '- **Phosphorus**: 700 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 700 mg/d
# Checking line: '- **Selenium**: 55 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 55 μg/d
# Checking line: '- **Zinc**: 8 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 8 mg/d
# Checking line: '- **Potassium**: 2600 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2600 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '## Females 51-70 years', Match: True
# Created document for group: Females 31-50 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1200 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1200 mg/d
# Checking line: '- **Chromium**: 20 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 20 μg/d
# Checking line: '- **Copper**: 900 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 900 μg/d
# Checking line: '- **Fluoride**: 3 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 3 mg/d
# Checking line: '- **Iodine**: 150 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 150 μg/d
# Checking line: '- **Iron**: 8 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 8 mg/d
# Checking line: '- **Magnesium**: 320 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 320 mg/d
# Checking line: '- **Manganese**: 1.8 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 1.8 mg/d
# Checking line: '- **Molybdenum**: 45 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 45 μg/d
# Checking line: '- **Phosphorus**: 700 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 700 mg/d
# Checking line: '- **Selenium**: 55 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 55 μg/d
# Checking line: '- **Zinc**: 8 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 8 mg/d
# Checking line: '- **Potassium**: 2600 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2600 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2 g/d
# Checking line: '## Females > 70 years', Match: True
# Created document for group: Females 51-70 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1200 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1200 mg/d
# Checking line: '- **Chromium**: 20 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 20 μg/d
# Checking line: '- **Copper**: 900 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 900 μg/d
# Checking line: '- **Fluoride**: 3 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 3 mg/d
# Checking line: '- **Iodine**: 150 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 150 μg/d
# Checking line: '- **Iron**: 8 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 8 mg/d
# Checking line: '- **Magnesium**: 320 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 320 mg/d
# Checking line: '- **Manganese**: 1.8 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 1.8 mg/d
# Checking line: '- **Molybdenum**: 45 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 45 μg/d
# Checking line: '- **Phosphorus**: 700 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 700 mg/d
# Checking line: '- **Selenium**: 55 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 55 μg/d
# Checking line: '- **Zinc**: 8 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 8 mg/d
# Checking line: '- **Potassium**: 2600 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2600 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 1.8 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 1.8 g/d
# Checking line: '## Pregnancy 14-18 years', Match: True
# Created document for group: Females > 70 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1300 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1300 mg/d
# Checking line: '- **Chromium**: 29 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 29 μg/d
# Checking line: '- **Copper**: 1000 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 1000 μg/d
# Checking line: '- **Fluoride**: 3 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 3 mg/d
# Checking line: '- **Iodine**: 220 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 220 μg/d
# Checking line: '- **Iron**: 27 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 27 mg/d
# Checking line: '- **Magnesium**: 400 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 400 mg/d
# Checking line: '- **Manganese**: 2 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 2 mg/d
# Checking line: '- **Molybdenum**: 50 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 50 μg/d
# Checking line: '- **Phosphorus**: 1250 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 1250 mg/d
# Checking line: '- **Selenium**: 60 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 60 μg/d
# Checking line: '- **Zinc**: 12 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 12 mg/d
# Checking line: '- **Potassium**: 2600 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2600 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '## Pregnancy 19-30 years', Match: True
# Created document for group: Pregnancy 14-18 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1000 mg/d
# Checking line: '- **Chromium**: 30 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 30 μg/d
# Checking line: '- **Copper**: 1000 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 1000 μg/d
# Checking line: '- **Fluoride**: 3 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 3 mg/d
# Checking line: '- **Iodine**: 220 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 220 μg/d
# Checking line: '- **Iron**: 27 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 27 mg/d
# Checking line: '- **Magnesium**: 350 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 350 mg/d
# Checking line: '- **Manganese**: 2 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 2 mg/d
# Checking line: '- **Molybdenum**: 50 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 50 μg/d
# Checking line: '- **Phosphorus**: 700 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 700 mg/d
# Checking line: '- **Selenium**: 60 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 60 μg/d
# Checking line: '- **Zinc**: 11 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 11 mg/d
# Checking line: '- **Potassium**: 2900 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2900 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '## Pregnancy 31-50 years', Match: True
# Created document for group: Pregnancy 19-30 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1000 mg/d
# Checking line: '- **Chromium**: 30 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 30 μg/d
# Checking line: '- **Copper**: 1000 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 1000 μg/d
# Checking line: '- **Fluoride**: 3 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 3 mg/d
# Checking line: '- **Iodine**: 220 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 220 μg/d
# Checking line: '- **Iron**: 27 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 27 mg/d
# Checking line: '- **Magnesium**: 360 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 360 mg/d
# Checking line: '- **Manganese**: 2 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 2 mg/d
# Checking line: '- **Molybdenum**: 50 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 50 μg/d
# Checking line: '- **Phosphorus**: 700 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 700 mg/d
# Checking line: '- **Selenium**: 60 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 60 μg/d
# Checking line: '- **Zinc**: 11 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 11 mg/d
# Checking line: '- **Potassium**: 2900 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2900 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '## Lactation 14-18 years', Match: True
# Created document for group: Pregnancy 31-50 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1300 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1300 mg/d
# Checking line: '- **Chromium**: 44 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 44 μg/d
# Checking line: '- **Copper**: 1300 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 1300 μg/d
# Checking line: '- **Fluoride**: 3 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 3 mg/d
# Checking line: '- **Iodine**: 290 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 290 μg/d
# Checking line: '- **Iron**: 10 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 10 mg/d
# Checking line: '- **Magnesium**: 360 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 360 mg/d
# Checking line: '- **Manganese**: 2.6 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 2.6 mg/d
# Checking line: '- **Molybdenum**: 50 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 50 μg/d
# Checking line: '- **Phosphorus**: 1250 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 1250 mg/d
# Checking line: '- **Selenium**: 70 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 70 μg/d
# Checking line: '- **Zinc**: 13 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 13 mg/d
# Checking line: '- **Potassium**: 2500 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2500 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '## Lactation 19-30 years', Match: True
# Created document for group: Lactation 14-18 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1000 mg/d
# Checking line: '- **Chromium**: 45 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 45 μg/d
# Checking line: '- **Copper**: 1300 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 1300 μg/d
# Checking line: '- **Fluoride**: 3 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 3 mg/d
# Checking line: '- **Iodine**: 290 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 290 μg/d
# Checking line: '- **Iron**: 9 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 9 mg/d
# Checking line: '- **Magnesium**: 310 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 310 mg/d
# Checking line: '- **Manganese**: 2.6 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 2.6 mg/d
# Checking line: '- **Molybdenum**: 50 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 50 μg/d
# Checking line: '- **Phosphorus**: 700 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 700 mg/d
# Checking line: '- **Selenium**: 70 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 70 μg/d
# Checking line: '- **Zinc**: 12 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 12 mg/d
# Checking line: '- **Potassium**: 2800 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2800 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '## Lactation 31-50 years', Match: True
# Created document for group: Lactation 19-30 years, Section: DRI_Minerals
# Checking line: '- **Calcium**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 1000 mg/d
# Checking line: '- **Chromium**: 45 μg/d', Match: False
# Parsed nutrient line: - **Chromium**: 45 μg/d
# Checking line: '- **Copper**: 1300 μg/d', Match: False
# Parsed nutrient line: - **Copper**: 1300 μg/d
# Checking line: '- **Fluoride**: 3 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 3 mg/d
# Checking line: '- **Iodine**: 290 μg/d', Match: False
# Parsed nutrient line: - **Iodine**: 290 μg/d
# Checking line: '- **Iron**: 9 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 9 mg/d
# Checking line: '- **Magnesium**: 320 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 320 mg/d
# Checking line: '- **Manganese**: 2.6 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 2.6 mg/d
# Checking line: '- **Molybdenum**: 50 μg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 50 μg/d
# Checking line: '- **Phosphorus**: 700 mg/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 700 mg/d
# Checking line: '- **Selenium**: 70 μg/d', Match: False
# Parsed nutrient line: - **Selenium**: 70 μg/d
# Checking line: '- **Zinc**: 12 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 12 mg/d
# Checking line: '- **Potassium**: 2800 mg/d', Match: False
# Parsed nutrient line: - **Potassium**: 2800 mg/d
# Checking line: '- **Sodium**: 1500 mg/d', Match: False
# Parsed nutrient line: - **Sodium**: 1500 mg/d
# Checking line: '- **Chloride**: 2.3 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 2.3 g/d
# Checking line: '-------------------------------------------------------------------------', Match: False
# Created document for group: Lactation 31-50 years, Section: DRI_Minerals
# Checking line: '# Dietary Reference Intakes for Vitamins and Macronutrients', Match: False
# Checking line: '## Infants 0-6 months', Match: True
# Checking line: '- **Vitamin A**: 400 μg/d', Match: False
# Parsed nutrient line: - **Vitamin A**: 400 μg/d
# Checking line: '- **Vitamin C**: 40 mg/d', Match: False
# Parsed nutrient line: - **Vitamin C**: 40 mg/d
# Checking line: '- **Vitamin D**: 10 μg/d', Match: False
# Parsed nutrient line: - **Vitamin D**: 10 μg/d
# Checking line: '- **Vitamin E**: 4 mg/d', Match: False
# Parsed nutrient line: - **Vitamin E**: 4 mg/d
# Checking line: '- **Vitamin K**: 2 μg/d', Match: False
# Parsed nutrient line: - **Vitamin K**: 2 μg/d
# Checking line: '- **Thiamin**: 0.2 mg/d', Match: False
# Parsed nutrient line: - **Thiamin**: 0.2 mg/d
# Checking line: '- **Riboflavin**: 0.3 mg/d', Match: False
# Parsed nutrient line: - **Riboflavin**: 0.3 mg/d
# Checking line: '- **Niacin**: 2 mg/d', Match: False
# Parsed nutrient line: - **Niacin**: 2 mg/d
# Checking line: '- **Vitamin B6**: 0.1 mg/d', Match: False
# Parsed nutrient line: - **Vitamin B6**: 0.1 mg/d
# Checking line: '- **Folate**: 65 μg/d', Match: False
# Parsed nutrient line: - **Folate**: 65 μg/d
# Checking line: '- **Vitamin B12**: 0.4 μg/d', Match: False
# Parsed nutrient line: - **Vitamin B12**: 0.4 μg/d
# Checking line: '- **Pantothenic Acid**: 1.7 mg/d', Match: False
# Parsed nutrient line: - **Pantothenic Acid**: 1.7 mg/d
# Checking line: '- **Biotin**: 5 μg/d', Match: False
# Parsed nutrient line: - **Biotin**: 5 μg/d
# Checking line: '- **Choline**: 125 mg/d', Match: False
# Parsed nutrient line: - **Choline**: 125 mg/d
# Checking line: '- **Total Water**: 0.7 L/d', Match: False
# Parsed nutrient line: - **Total Water**: 0.7 L/d
# Checking line: '- **Carbohydrate**: 60 g/d', Match: False
# Parsed nutrient line: - **Carbohydrate**: 60 g/d
# Checking line: '- **Fat**: 31 g/d', Match: False
# Parsed nutrient line: - **Fat**: 31 g/d
# Checking line: '- **Linoleic Acid**: 4.4 g/d', Match: False
# Parsed nutrient line: - **Linoleic Acid**: 4.4 g/d
# Checking line: '- **α-Linolenic Acid**: 0.5 g/d', Match: False
# Parsed nutrient line: - **α-Linolenic Acid**: 0.5 g/d
# Checking line: '- **Protein**: 9.1 g/d', Match: False
# Parsed nutrient line: - **Protein**: 9.1 g/d
# Checking line: '## Infants 7-12 months', Match: True
# Created document for group: Infants 0-6 months, Section: DRI_Vitamins_Macros
# Checking line: '- **Vitamin A**: 500 μg/d', Match: False
# Parsed nutrient line: - **Vitamin A**: 500 μg/d
# Checking line: '- **Vitamin C**: 50 mg/d', Match: False
# Parsed nutrient line: - **Vitamin C**: 50 mg/d
# Checking line: '- **Vitamin D**: 10 μg/d', Match: False
# Parsed nutrient line: - **Vitamin D**: 10 μg/d
# Checking line: '- **Vitamin E**: 5 mg/d', Match: False
# Parsed nutrient line: - **Vitamin E**: 5 mg/d
# Checking line: '- **Vitamin K**: 2.5 μg/d', Match: False
# Parsed nutrient line: - **Vitamin K**: 2.5 μg/d
# Checking line: '- **Thiamin**: 0.3 mg/d', Match: False
# Parsed nutrient line: - **Thiamin**: 0.3 mg/d
# Checking line: '- **Riboflavin**: 0.4 mg/d', Match: False
# Parsed nutrient line: - **Riboflavin**: 0.4 mg/d
# Checking line: '- **Niacin**: 4 mg/d', Match: False
# Parsed nutrient line: - **Niacin**: 4 mg/d
# Checking line: '- **Vitamin B6**: 0.3 mg/d', Match: False
# Parsed nutrient line: - **Vitamin B6**: 0.3 mg/d
# Checking line: '- **Folate**: 80 μg/d', Match: False
# Parsed nutrient line: - **Folate**: 80 μg/d
# Checking line: '- **Vitamin B12**: 0.5 μg/d', Match: False
# Parsed nutrient line: - **Vitamin B12**: 0.5 μg/d
# Checking line: '- **Pantothenic Acid**: 1.8 mg/d', Match: False
# Parsed nutrient line: - **Pantothenic Acid**: 1.8 mg/d
# Checking line: '- **Biotin**: 6 μg/d', Match: False
# Parsed nutrient line: - **Biotin**: 6 μg/d
# Checking line: '- **Choline**: 150 mg/d', Match: False
# Parsed nutrient line: - **Choline**: 150 mg/d
# Checking line: '- **Total Water**: 0.8 L/d', Match: False
# Parsed nutrient line: - **Total Water**: 0.8 L/d
# Checking line: '- **Carbohydrate**: 95 g/d', Match: False
# Parsed nutrient line: - **Carbohydrate**: 95 g/d
# Checking line: '- **Fat**: 30 g/d', Match: False
# Parsed nutrient line: - **Fat**: 30 g/d
# Checking line: '- **Linoleic Acid**: 4.6 g/d', Match: False
# Parsed nutrient line: - **Linoleic Acid**: 4.6 g/d
# Checking line: '- **α-Linolenic Acid**: 0.5 g/d', Match: False
# Parsed nutrient line: - **α-Linolenic Acid**: 0.5 g/d
# Checking line: '- **Protein**: 11 g/d', Match: False
# Parsed nutrient line: - **Protein**: 11 g/d
# Checking line: '## Children 1-3 years', Match: True
# Created document for group: Infants 7-12 months, Section: DRI_Vitamins_Macros
# Checking line: '- **Vitamin A**: 300 μg/d', Match: False
# Parsed nutrient line: - **Vitamin A**: 300 μg/d
# Checking line: '- **Vitamin C**: 15 mg/d', Match: False
# Parsed nutrient line: - **Vitamin C**: 15 mg/d
# Checking line: '- **Vitamin D**: 15 μg/d', Match: False
# Parsed nutrient line: - **Vitamin D**: 15 μg/d
# Checking line: '- **Vitamin E**: 6 mg/d', Match: False
# Parsed nutrient line: - **Vitamin E**: 6 mg/d
# Checking line: '- **Vitamin K**: 30 μg/d', Match: False
# Parsed nutrient line: - **Vitamin K**: 30 μg/d
# Checking line: '- **Thiamin**: 0.5 mg/d', Match: False
# Parsed nutrient line: - **Thiamin**: 0.5 mg/d
# Checking line: '- **Riboflavin**: 0.5 mg/d', Match: False
# Parsed nutrient line: - **Riboflavin**: 0.5 mg/d
# Checking line: '- **Niacin**: 6 mg/d', Match: False
# Parsed nutrient line: - **Niacin**: 6 mg/d
# Checking line: '- **Vitamin B6**: 0.5 mg/d', Match: False
# Parsed nutrient line: - **Vitamin B6**: 0.5 mg/d
# Checking line: '- **Folate**: 150 μg/d', Match: False
# Parsed nutrient line: - **Folate**: 150 μg/d
# Checking line: '- **Vitamin B12**: 0.9 μg/d', Match: False
# Parsed nutrient line: - **Vitamin B12**: 0.9 μg/d
# Checking line: '- **Pantothenic Acid**: 2 mg/d', Match: False
# Parsed nutrient line: - **Pantothenic Acid**: 2 mg/d
# Checking line: '- **Biotin**: 8 μg/d', Match: False
# Parsed nutrient line: - **Biotin**: 8 μg/d
# Checking line: '- **Choline**: 200 mg/d', Match: False
# Parsed nutrient line: - **Choline**: 200 mg/d
# Checking line: '- **Total Water**: 1.3 L/d', Match: False
# Parsed nutrient line: - **Total Water**: 1.3 L/d
# Checking line: '- **Carbohydrate**: 130 g/d', Match: False
# Parsed nutrient line: - **Carbohydrate**: 130 g/d
# Checking line: '- **Total Fiber**: 19 g/d', Match: False
# Parsed nutrient line: - **Total Fiber**: 19 g/d
# Checking line: '- **Linoleic Acid**: 7 g/d', Match: False
# Parsed nutrient line: - **Linoleic Acid**: 7 g/d
# Checking line: '- **α-Linolenic Acid**: 0.7 g/d', Match: False
# Parsed nutrient line: - **α-Linolenic Acid**: 0.7 g/d
# Checking line: '- **Protein**: 13 g/d', Match: False
# Parsed nutrient line: - **Protein**: 13 g/d
# Checking line: '## Children 4-8 years', Match: True
# Created document for group: Children 1-3 years, Section: DRI_Vitamins_Macros
# Checking line: '- **Vitamin A**: 400 μg/d', Match: False
# Parsed nutrient line: - **Vitamin A**: 400 μg/d
# Checking line: '- **Vitamin C**: 25 mg/d', Match: False
# Parsed nutrient line: - **Vitamin C**: 25 mg/d
# Checking line: '- **Vitamin D**: 15 μg/d', Match: False
# Parsed nutrient line: - **Vitamin D**: 15 μg/d
# Checking line: '- **Vitamin E**: 7 mg/d', Match: False
# Parsed nutrient line: - **Vitamin E**: 7 mg/d
# Checking line: '- **Vitamin K**: 55 μg/d', Match: False
# Parsed nutrient line: - **Vitamin K**: 55 μg/d
# Checking line: '- **Thiamin**: 0.6 mg/d', Match: False
# Parsed nutrient line: - **Thiamin**: 0.6 mg/d
# Checking line: '- **Riboflavin**: 0.6 mg/d', Match: False
# Parsed nutrient line: - **Riboflavin**: 0.6 mg/d
# Checking line: '- **Niacin**: 8 mg/d', Match: False
# Parsed nutrient line: - **Niacin**: 8 mg/d
# Checking line: '- **Vitamin B6**: 0.6 mg/d', Match: False
# Parsed nutrient line: - **Vitamin B6**: 0.6 mg/d
# Checking line: '- **Folate**: 200 μg/d', Match: False
# Parsed nutrient line: - **Folate**: 200 μg/d
# Checking line: '- **Vitamin B12**: 1.2 μg/d', Match: False
# Parsed nutrient line: - **Vitamin B12**: 1.2 μg/d
# Checking line: '- **Pantothenic Acid**: 3 mg/d', Match: False
# Parsed nutrient line: - **Pantothenic Acid**: 3 mg/d
# Checking line: '- **Biotin**: 12 μg/d', Match: False
# Parsed nutrient line: - **Biotin**: 12 μg/d
# Checking line: '- **Choline**: 250 mg/d', Match: False
# Parsed nutrient line: - **Choline**: 250 mg/d
# Checking line: '- **Total Water**: 1.7 L/d', Match: False
# Parsed nutrient line: - **Total Water**: 1.7 L/d
# Checking line: '- **Carbohydrate**: 130 g/d', Match: False
# Parsed nutrient line: - **Carbohydrate**: 130 g/d
# Checking line: '- **Total Fiber**: 25 g/d', Match: False
# Parsed nutrient line: - **Total Fiber**: 25 g/d
# Checking line: '- **Linoleic Acid**: 10 g/d', Match: False
# Parsed nutrient line: - **Linoleic Acid**: 10 g/d
# Checking line: '- **α-Linolenic Acid**: 0.9 g/d', Match: False
# Parsed nutrient line: - **α-Linolenic Acid**: 0.9 g/d
# Checking line: '- **Protein**: 19 g/d', Match: False
# Parsed nutrient line: - **Protein**: 19 g/d
# Checking line: '## Males 9-13 years', Match: True
# Created document for group: Children 4-8 years, Section: DRI_Vitamins_Macros
# Checking line: '- **Vitamin A**: 600 μg/d', Match: False
# Parsed nutrient line: - **Vitamin A**: 600 μg/d
# Checking line: '- **Vitamin C**: 45 mg/d', Match: False
# Parsed nutrient line: - **Vitamin C**: 45 mg/d
# Checking line: '- **Vitamin D**: 15 μg/d', Match: False
# Parsed nutrient line: - **Vitamin D**: 15 μg/d
# Checking line: '- **Vitamin E**: 11 mg/d', Match: False
# Parsed nutrient line: - **Vitamin E**: 11 mg/d
# Checking line: '- **Vitamin K**: 60 μg/d', Match: False
# Parsed nutrient line: - **Vitamin K**: 60 μg/d
# Checking line: '- **Thiamin**: 0.9 mg/d', Match: False
# Parsed nutrient line: - **Thiamin**: 0.9 mg/d
# Checking line: '- **Riboflavin**: 0.9 mg/d', Match: False
# Parsed nutrient line: - **Riboflavin**: 0.9 mg/d
# Checking line: '- **Niacin**: 12 mg/d', Match: False
# Parsed nutrient line: - **Niacin**: 12 mg/d
# Checking line: '- **Vitamin B6**: 1 mg/d', Match: False
# Parsed nutrient line: - **Vitamin B6**: 1 mg/d
# Checking line: '- **Folate**: 300 μg/d', Match: False
# Parsed nutrient line: - **Folate**: 300 μg/d
# Checking line: '- **Vitamin B12**: 1.8 μg/d', Match: False
# Parsed nutrient line: - **Vitamin B12**: 1.8 μg/d
# Checking line: '- **Pantothenic Acid**: 4 mg/d', Match: False
# Parsed nutrient line: - **Pantothenic Acid**: 4 mg/d
# Checking line: '- **Biotin**: 20 μg/d', Match: False
# Parsed nutrient line: - **Biotin**: 20 μg/d
# Checking line: '- **Choline**: 375 mg/d', Match: False
# Parsed nutrient line: - **Choline**: 375 mg/d
# Checking line: '- **Total Water**: 2.4 L/d', Match: False
# ...
# Checking line: '- **Boron**: 11 mg/d', Match: False
# Parsed nutrient line: - **Boron**: 11 mg/d
# Checking line: '- **Calcium**: 3000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 3000 mg/d
# Checking line: '- **Copper**: 5000 µg/d', Match: False
# Parsed nutrient line: - **Copper**: 5000 µg/d
# Checking line: '- **Fluoride**: 10 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 10 mg/d
# Checking line: '- **Iodine**: 600 µg/d', Match: False
# Parsed nutrient line: - **Iodine**: 600 µg/d
# Checking line: '- **Iron**: 40 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 40 mg/d
# Checking line: '- **Magnesium**: 350 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 350 mg/d
# Checking line: '- **Manganese**: 6 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 6 mg/d
# Checking line: '- **Molybdenum**: 1100 µg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 1100 µg/d
# Checking line: '- **Nickel**: 0.6 mg/d', Match: False
# Parsed nutrient line: - **Nickel**: 0.6 mg/d
# Checking line: '- **Phosphorus**: 4 g/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 4 g/d
# Checking line: '- **Selenium**: 280 µg/d', Match: False
# Parsed nutrient line: - **Selenium**: 280 µg/d
# Checking line: '- **Zinc**: 23 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 23 mg/d
# Checking line: '- **Chloride**: 3.4 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 3.4 g/d
# Checking line: '## Females 14-18 years', Match: True
# Created document for group: Females 9-13 years, Section: TUL
# Checking line: '- **Vitamin A**: 2800 µg/d', Match: False
# Parsed nutrient line: - **Vitamin A**: 2800 µg/d
# Checking line: '- **Vitamin C**: 1800 mg/d', Match: False
# Parsed nutrient line: - **Vitamin C**: 1800 mg/d
# Checking line: '- **Vitamin D**: 100 µg/d', Match: False
# Parsed nutrient line: - **Vitamin D**: 100 µg/d
# Checking line: '- **Vitamin E**: 800 mg/d', Match: False
# Parsed nutrient line: - **Vitamin E**: 800 mg/d
# Checking line: '- **Niacin**: 30 mg/d', Match: False
# Parsed nutrient line: - **Niacin**: 30 mg/d
# Checking line: '- **Vitamin B6**: 80 mg/d', Match: False
# Parsed nutrient line: - **Vitamin B6**: 80 mg/d
# Checking line: '- **Folate**: 800 µg/d', Match: False
# Parsed nutrient line: - **Folate**: 800 µg/d
# Checking line: '- **Choline**: 3 g/d', Match: False
# Parsed nutrient line: - **Choline**: 3 g/d
# Checking line: '- **Boron**: 17 mg/d', Match: False
# Parsed nutrient line: - **Boron**: 17 mg/d
# Checking line: '- **Calcium**: 3000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 3000 mg/d
# Checking line: '- **Copper**: 8000 µg/d', Match: False
# Parsed nutrient line: - **Copper**: 8000 µg/d
# Checking line: '- **Fluoride**: 10 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 10 mg/d
# Checking line: '- **Iodine**: 900 µg/d', Match: False
# Parsed nutrient line: - **Iodine**: 900 µg/d
# Checking line: '- **Iron**: 45 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 45 mg/d
# Checking line: '- **Magnesium**: 350 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 350 mg/d
# Checking line: '- **Manganese**: 9 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 9 mg/d
# Checking line: '- **Molybdenum**: 1700 µg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 1700 µg/d
# Checking line: '- **Nickel**: 1 mg/d', Match: False
# Parsed nutrient line: - **Nickel**: 1 mg/d
# Checking line: '- **Phosphorus**: 4 g/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 4 g/d
# Checking line: '- **Selenium**: 400 µg/d', Match: False
# Parsed nutrient line: - **Selenium**: 400 µg/d
# Checking line: '- **Zinc**: 34 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 34 mg/d
# Checking line: '- **Chloride**: 3.6 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 3.6 g/d
# Checking line: '## Females 19-70+ years', Match: True
# Created document for group: Females 14-18 years, Section: TUL
# Checking line: '- **Vitamin A**: 3000 µg/d', Match: False
# Parsed nutrient line: - **Vitamin A**: 3000 µg/d
# Checking line: '- **Vitamin C**: 2000 mg/d', Match: False
# Parsed nutrient line: - **Vitamin C**: 2000 mg/d
# Checking line: '- **Vitamin D**: 100 µg/d', Match: False
# Parsed nutrient line: - **Vitamin D**: 100 µg/d
# Checking line: '- **Vitamin E**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Vitamin E**: 1000 mg/d
# Checking line: '- **Niacin**: 35 mg/d', Match: False
# Parsed nutrient line: - **Niacin**: 35 mg/d
# Checking line: '- **Vitamin B6**: 100 mg/d', Match: False
# Parsed nutrient line: - **Vitamin B6**: 100 mg/d
# Checking line: '- **Folate**: 1000 µg/d', Match: False
# Parsed nutrient line: - **Folate**: 1000 µg/d
# Checking line: '- **Choline**: 3.5 g/d', Match: False
# Parsed nutrient line: - **Choline**: 3.5 g/d
# Checking line: '- **Boron**: 20 mg/d', Match: False
# Parsed nutrient line: - **Boron**: 20 mg/d
# Checking line: '- **Calcium**: 2500 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 2500 mg/d
# Checking line: '- **Copper**: 10000 µg/d', Match: False
# Parsed nutrient line: - **Copper**: 10000 µg/d
# Checking line: '- **Fluoride**: 10 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 10 mg/d
# Checking line: '- **Iodine**: 1100 µg/d', Match: False
# Parsed nutrient line: - **Iodine**: 1100 µg/d
# Checking line: '- **Iron**: 45 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 45 mg/d
# Checking line: '- **Magnesium**: 350 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 350 mg/d
# Checking line: '- **Manganese**: 11 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 11 mg/d
# Checking line: '- **Molybdenum**: 2000 µg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 2000 µg/d
# Checking line: '- **Nickel**: 1 mg/d', Match: False
# Parsed nutrient line: - **Nickel**: 1 mg/d
# Checking line: '- **Phosphorus**: 4 g/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 4 g/d
# Checking line: '- **Selenium**: 400 µg/d', Match: False
# Parsed nutrient line: - **Selenium**: 400 µg/d
# Checking line: '- **Vanadium**: 1.8 mg/d', Match: False
# Parsed nutrient line: - **Vanadium**: 1.8 mg/d
# Checking line: '- **Zinc**: 40 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 40 mg/d
# Checking line: '- **Chloride**: 3.6 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 3.6 g/d
# Checking line: '## Pregnancy 14-18 years', Match: True
# Created document for group: Females 19-70+ years, Section: TUL
# Checking line: '- **Vitamin A**: 2800 µg/d', Match: False
# Parsed nutrient line: - **Vitamin A**: 2800 µg/d
# Checking line: '- **Vitamin C**: 1800 mg/d', Match: False
# Parsed nutrient line: - **Vitamin C**: 1800 mg/d
# Checking line: '- **Vitamin D**: 100 µg/d', Match: False
# Parsed nutrient line: - **Vitamin D**: 100 µg/d
# Checking line: '- **Vitamin E**: 800 mg/d', Match: False
# Parsed nutrient line: - **Vitamin E**: 800 mg/d
# Checking line: '- **Niacin**: 30 mg/d', Match: False
# Parsed nutrient line: - **Niacin**: 30 mg/d
# Checking line: '- **Vitamin B6**: 80 mg/d', Match: False
# Parsed nutrient line: - **Vitamin B6**: 80 mg/d
# Checking line: '- **Folate**: 800 µg/d', Match: False
# Parsed nutrient line: - **Folate**: 800 µg/d
# Checking line: '- **Choline**: 3 g/d', Match: False
# Parsed nutrient line: - **Choline**: 3 g/d
# Checking line: '- **Boron**: 17 mg/d', Match: False
# Parsed nutrient line: - **Boron**: 17 mg/d
# Checking line: '- **Calcium**: 3000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 3000 mg/d
# Checking line: '- **Copper**: 8000 µg/d', Match: False
# Parsed nutrient line: - **Copper**: 8000 µg/d
# Checking line: '- **Fluoride**: 10 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 10 mg/d
# Checking line: '- **Iodine**: 900 µg/d', Match: False
# Parsed nutrient line: - **Iodine**: 900 µg/d
# Checking line: '- **Iron**: 45 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 45 mg/d
# Checking line: '- **Magnesium**: 350 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 350 mg/d
# Checking line: '- **Manganese**: 9 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 9 mg/d
# Checking line: '- **Molybdenum**: 1700 µg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 1700 µg/d
# Checking line: '- **Nickel**: 1 mg/d', Match: False
# Parsed nutrient line: - **Nickel**: 1 mg/d
# Checking line: '- **Phosphorus**: 3.5 g/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 3.5 g/d
# Checking line: '- **Selenium**: 400 µg/d', Match: False
# Parsed nutrient line: - **Selenium**: 400 µg/d
# Checking line: '- **Zinc**: 34 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 34 mg/d
# Checking line: '- **Chloride**: 3.6 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 3.6 g/d
# Checking line: '## Pregnancy 19-50 years', Match: True
# Created document for group: Pregnancy 14-18 years, Section: TUL
# Checking line: '- **Vitamin A**: 3000 µg/d', Match: False
# Parsed nutrient line: - **Vitamin A**: 3000 µg/d
# Checking line: '- **Vitamin C**: 2000 mg/d', Match: False
# Parsed nutrient line: - **Vitamin C**: 2000 mg/d
# Checking line: '- **Vitamin D**: 100 µg/d', Match: False
# Parsed nutrient line: - **Vitamin D**: 100 µg/d
# Checking line: '- **Vitamin E**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Vitamin E**: 1000 mg/d
# Checking line: '- **Niacin**: 35 mg/d', Match: False
# Parsed nutrient line: - **Niacin**: 35 mg/d
# Checking line: '- **Vitamin B6**: 100 mg/d', Match: False
# Parsed nutrient line: - **Vitamin B6**: 100 mg/d
# Checking line: '- **Folate**: 1000 µg/d', Match: False
# Parsed nutrient line: - **Folate**: 1000 µg/d
# Checking line: '- **Choline**: 3.5 g/d', Match: False
# Parsed nutrient line: - **Choline**: 3.5 g/d
# Checking line: '- **Boron**: 20 mg/d', Match: False
# Parsed nutrient line: - **Boron**: 20 mg/d
# Checking line: '- **Calcium**: 2500 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 2500 mg/d
# Checking line: '- **Copper**: 10000 µg/d', Match: False
# Parsed nutrient line: - **Copper**: 10000 µg/d
# Checking line: '- **Fluoride**: 10 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 10 mg/d
# Checking line: '- **Iodine**: 1100 µg/d', Match: False
# Parsed nutrient line: - **Iodine**: 1100 µg/d
# Checking line: '- **Iron**: 45 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 45 mg/d
# Checking line: '- **Magnesium**: 350 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 350 mg/d
# Checking line: '- **Manganese**: 11 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 11 mg/d
# Checking line: '- **Molybdenum**: 2000 µg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 2000 µg/d
# Checking line: '- **Nickel**: 1 mg/d', Match: False
# Parsed nutrient line: - **Nickel**: 1 mg/d
# Checking line: '- **Phosphorus**: 3.5 g/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 3.5 g/d
# Checking line: '- **Selenium**: 400 µg/d', Match: False
# Parsed nutrient line: - **Selenium**: 400 µg/d
# Checking line: '- **Zinc**: 40 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 40 mg/d
# Checking line: '- **Chloride**: 3.6 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 3.6 g/d
# Checking line: '## Lactation 14-18 years', Match: True
# Created document for group: Pregnancy 19-50 years, Section: TUL
# Checking line: '- **Vitamin A**: 2800 µg/d', Match: False
# Parsed nutrient line: - **Vitamin A**: 2800 µg/d
# Checking line: '- **Vitamin C**: 1800 mg/d', Match: False
# Parsed nutrient line: - **Vitamin C**: 1800 mg/d
# Checking line: '- **Vitamin D**: 100 µg/d', Match: False
# Parsed nutrient line: - **Vitamin D**: 100 µg/d
# Checking line: '- **Vitamin E**: 800 mg/d', Match: False
# Parsed nutrient line: - **Vitamin E**: 800 mg/d
# Checking line: '- **Niacin**: 30 mg/d', Match: False
# Parsed nutrient line: - **Niacin**: 30 mg/d
# Checking line: '- **Vitamin B6**: 80 mg/d', Match: False
# Parsed nutrient line: - **Vitamin B6**: 80 mg/d
# Checking line: '- **Folate**: 800 µg/d', Match: False
# Parsed nutrient line: - **Folate**: 800 µg/d
# Checking line: '- **Choline**: 3 g/d', Match: False
# Parsed nutrient line: - **Choline**: 3 g/d
# Checking line: '- **Boron**: 17 mg/d', Match: False
# Parsed nutrient line: - **Boron**: 17 mg/d
# Checking line: '- **Calcium**: 3000 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 3000 mg/d
# Checking line: '- **Copper**: 8000 µg/d', Match: False
# Parsed nutrient line: - **Copper**: 8000 µg/d
# Checking line: '- **Fluoride**: 10 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 10 mg/d
# Checking line: '- **Iodine**: 900 µg/d', Match: False
# Parsed nutrient line: - **Iodine**: 900 µg/d
# Checking line: '- **Iron**: 45 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 45 mg/d
# Checking line: '- **Magnesium**: 350 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 350 mg/d
# Checking line: '- **Manganese**: 9 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 9 mg/d
# Checking line: '- **Molybdenum**: 1700 µg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 1700 µg/d
# Checking line: '- **Nickel**: 1 mg/d', Match: False
# Parsed nutrient line: - **Nickel**: 1 mg/d
# Checking line: '- **Phosphorus**: 4 g/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 4 g/d
# Checking line: '- **Selenium**: 400 µg/d', Match: False
# Parsed nutrient line: - **Selenium**: 400 µg/d
# Checking line: '- **Zinc**: 34 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 34 mg/d
# Checking line: '- **Chloride**: 3.6 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 3.6 g/d
# Checking line: '## Lactation 19-50 years', Match: True
# Created document for group: Lactation 14-18 years, Section: TUL
# Checking line: '- **Vitamin A**: 3000 µg/d', Match: False
# Parsed nutrient line: - **Vitamin A**: 3000 µg/d
# Checking line: '- **Vitamin C**: 2000 mg/d', Match: False
# Parsed nutrient line: - **Vitamin C**: 2000 mg/d
# Checking line: '- **Vitamin D**: 100 µg/d', Match: False
# Parsed nutrient line: - **Vitamin D**: 100 µg/d
# Checking line: '- **Vitamin E**: 1000 mg/d', Match: False
# Parsed nutrient line: - **Vitamin E**: 1000 mg/d
# Checking line: '- **Niacin**: 35 mg/d', Match: False
# Parsed nutrient line: - **Niacin**: 35 mg/d
# Checking line: '- **Vitamin B6**: 100 mg/d', Match: False
# Parsed nutrient line: - **Vitamin B6**: 100 mg/d
# Checking line: '- **Folate**: 1000 µg/d', Match: False
# Parsed nutrient line: - **Folate**: 1000 µg/d
# Checking line: '- **Choline**: 3.5 g/d', Match: False
# Parsed nutrient line: - **Choline**: 3.5 g/d
# Checking line: '- **Boron**: 20 mg/d', Match: False
# Parsed nutrient line: - **Boron**: 20 mg/d
# Checking line: '- **Calcium**: 2500 mg/d', Match: False
# Parsed nutrient line: - **Calcium**: 2500 mg/d
# Checking line: '- **Copper**: 10000 µg/d', Match: False
# Parsed nutrient line: - **Copper**: 10000 µg/d
# Checking line: '- **Fluoride**: 10 mg/d', Match: False
# Parsed nutrient line: - **Fluoride**: 10 mg/d
# Checking line: '- **Iodine**: 1100 µg/d', Match: False
# Parsed nutrient line: - **Iodine**: 1100 µg/d
# Checking line: '- **Iron**: 45 mg/d', Match: False
# Parsed nutrient line: - **Iron**: 45 mg/d
# Checking line: '- **Magnesium**: 350 mg/d', Match: False
# Parsed nutrient line: - **Magnesium**: 350 mg/d
# Checking line: '- **Manganese**: 11 mg/d', Match: False
# Parsed nutrient line: - **Manganese**: 11 mg/d
# Checking line: '- **Molybdenum**: 2000 µg/d', Match: False
# Parsed nutrient line: - **Molybdenum**: 2000 µg/d
# Checking line: '- **Nickel**: 1 mg/d', Match: False
# Parsed nutrient line: - **Nickel**: 1 mg/d
# Checking line: '- **Phosphorus**: 4 g/d', Match: False
# Parsed nutrient line: - **Phosphorus**: 4 g/d
# Checking line: '- **Selenium**: 400 µg/d', Match: False
# Parsed nutrient line: - **Selenium**: 400 µg/d
# Checking line: '- **Zinc**: 40 mg/d', Match: False
# Parsed nutrient line: - **Zinc**: 40 mg/d
# Checking line: '- **Chloride**: 3.6 g/d', Match: False
# Parsed nutrient line: - **Chloride**: 3.6 g/d
# Created document for group: Lactation 19-50 years, Section: TUL
# Created 80 documents
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Created vector store with 80 documents in collection 'nutrition_data'

# %%
# !pip install -qU langchain-perplexity

# %%
from langchain_perplexity import ChatPerplexity
from google.colab import userdata

pplx_api_key = userdata.get('PERPLEX_API_KEY')

llm_1 = ChatPerplexity(pplx_api_key=pplx_api_key, model="sonar", temperature=0.0)

# %%
from typing import List, Dict, Any
import re
from langchain.prompts import ChatPromptTemplate
from langchain.schema import Document
from langchain_perplexity import ChatPerplexity

class PerplexityRAGQuery:
    def __init__(self, vectorstore, perplexity_api_key: str):
        """
        Initialize with vector store and Perplexity API key
        """
        self.vectorstore = vectorstore
        self.client = ChatPerplexity(pplx_api_key=perplexity_api_key, model="sonar", temperature=0.0)

        self.prompt_template = ChatPromptTemplate.from_template(
            """
            You are a nutrition assistant. Use only the provided context to construct a nutrient requirement list.

            Instructions:
            1. Use ONLY the context provided, which is filtered for the specific demographic group.
            2. Output ONLY a clean list of nutrients and their values, one per line, in the format: "Nutrient Name: Value [TUL : TUL Value]"
            3. Do not include any bullet points, dashes, asterisks, or markdown formatting.
            4. Do not include any introductions, conclusions, explanations, or additional text.
            5. Do not include section headers or document references.
            6. If no relevant data is found, return "Data not found".
            7. Make sure the values do not exceed specified TULs.
            8. The lives of patients are in your hands. False information leads to serious health impairment or death.

            Context:
            {context}

            User Query:
            {question}

            Output format example:
            Calcium: 1000 mg/d [TUL : 2500 mg/d]
            Iron: 8 mg/d [TUL : 45 mg/d]
            Vitamin C: 90 mg/d [TUL : 2000 mg/d]
            """
        )

    def extract_demographic_from_query(self, query: str) -> tuple[int, str]:
        """
        Extract age and sex from the query using regex
        """
        age_pattern = r'(\d{1,3})\s*(?:year(?:s)?(?:\s|-)?old)?'
        age_match = re.search(age_pattern, query, re.IGNORECASE)
        age = int(age_match.group(1)) if age_match else None

        sex_pattern = r'\b(male|man|female|woman)\b'
        sex_match = re.search(sex_pattern, query, re.IGNORECASE)
        sex = sex_match.group(1).lower() if sex_match else None
        sex = 'male' if sex in ['man', 'male'] else 'female' if sex in ['woman', 'female'] else None

        return age, sex

    def get_target_headers(self, age: int, sex: str) -> List[str]:
        """
        Get standardized target headers for the demographic
        """
        if age < 1:
            return ["Infants 0-6 months", "Infants 7-12 months"]
        elif 1 <= age <= 3:
            return ["Children 1-3 years"]
        elif 4 <= age <= 8:
            return ["Children 4-8 years"]
        elif 9 <= age <= 13:
            return [f"{sex.capitalize()}s 9-13 years"]
        elif 14 <= age <= 18:
            return [f"{sex.capitalize()}s 14-18 years"]
        elif 19 <= age <= 30:
            headers = [f"{sex.capitalize()}s 19-30 years"]
            headers.append(f"{sex.capitalize()}s 19-70+ years")
            return headers
        elif 31 <= age <= 50:
            headers = [f"{sex.capitalize()}s 31-50 years"]
            headers.append(f"{sex.capitalize()}s 19-70+ years")
            return headers
        elif 51 <= age <= 70:
            headers = [f"{sex.capitalize()}s 51-70 years"]
            headers.append(f"{sex.capitalize()}s 19-70+ years")
            return headers
        else:  # > 70
            headers = [f"{sex.capitalize()}s > 70 years"]
            headers.append(f"{sex.capitalize()}s 19-70+ years")
            return headers

    def retrieve_relevant_documents(self, query: str, age: int = None, sex: str = None, k: int = 10) -> List[Document]:
        """
        Retrieve documents for the demographic from all relevant sections
        """
        if age is None or sex is None:
            age, sex = self.extract_demographic_from_query(query)

        if not age or not sex:
            return []

        target_headers = self.get_target_headers(age, sex)
        sections = ["DRI_Minerals", "DRI_Vitamins_Macros", "EAR", "TUL"]

        all_documents = []

        for section in sections:
            for header in target_headers:
                filters = {
                    "$and": [
                        {"demographic_group": {"$eq": header}},
                        {"section_type": {"$eq": section}}
                    ]
                }

                try:
                    docs = self.vectorstore.similarity_search(
                        query,
                        k=k,
                        filter=filters
                    )

                    validated_docs = [
                        doc for doc in docs
                        if (doc.metadata.get("demographic_group") == header and
                            doc.metadata.get("section_type") == section)
                    ]

                    all_documents.extend(validated_docs)

                    if validated_docs:
                        break

                except Exception:
                    continue

        unique_docs = []
        seen_content = set()
        for doc in all_documents:
            content_hash = hash(doc.page_content)
            if content_hash not in seen_content:
                unique_docs.append(doc)
                seen_content.add(content_hash)

        return unique_docs

    def format_context(self, documents: List[Document]) -> str:
        """
        Format retrieved documents into context string
        """
        context_parts = []
        for i, doc in enumerate(documents):
            context_part = f"Document {i+1} [{doc.metadata.get('demographic_group', 'Unknown')} - {doc.metadata.get('section_type', 'Unknown')}]\n{doc.page_content}\n"
            context_parts.append(context_part)
        return "\n".join(context_parts)

    def query_perplexity(self, prompt: str, model: str = "sonar") -> str:
        """
        Query Perplexity API with the formatted prompt
        """
        try:
            response = self.client.invoke(prompt)
            return response.content
        except Exception:
            return ""

    def answer_query(self, question: str, age: int = None, sex: str = None, model: str = "sonar") -> str:
        """
        Complete RAG pipeline: retrieve, format, and query
        """
        if age is None or sex is None:
            age, sex = self.extract_demographic_from_query(question)

        if not age or not sex:
            return f"The ideal nutritional intake for a {age or 'unknown'} year old {sex or 'unknown'} is as follows:\n"

        documents = self.retrieve_relevant_documents(question, age, sex)

        if not documents:
            return f"The ideal nutritional intake for a {age} year old {sex} is as follows:\n"

        context = self.format_context(documents)

        formatted_prompt = self.prompt_template.format(
            context=context,
            question=question
        )

        nutrient_list = self.query_perplexity(formatted_prompt, model)

        return f"The ideal nutritional intake for a {age} year old {sex} is as follows:\n{nutrient_list}"


def test_nutrition_query(processor, vectorstore, perplexity_api_key: str):
    """
    Test function with the specified query
    """
    rag_system = PerplexityRAGQuery(vectorstore, perplexity_api_key)
    age = int(input("Enter the user's age :"))
    sex = input("Enter the user's sex (male/female) :")
    test_query = f"What are the ideal nutritional requirements for a {age} year old {sex}?"
    result = rag_system.answer_query(question=test_query)
    print(result)
    return result

# %%
result = test_nutrition_query(processor, vectorstore, pplx_api_key)
# Out:
# Enter the user's age :68
# Enter the user's sex (male/female) :male
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# The ideal nutritional intake for a 68 year old male is as follows:
# Calcium: 1000 mg/d [TUL : 2500 mg/d]
# Chromium: 30 μg/d [TUL : Data not found]
# Copper: 900 μg/d [TUL : 10000 μg/d]
# Fluoride: 4 mg/d [TUL : 10 mg/d]
# Iodine: 150 μg/d [TUL : 1100 μg/d]
# Iron: 8 mg/d [TUL : 45 mg/d]
# Magnesium: 420 mg/d [TUL : 350 mg/d]
# Manganese: 2.3 mg/d [TUL : 11 mg/d]
# Molybdenum: 45 μg/d [TUL : 2000 μg/d]
# Phosphorus: 700 mg/d [TUL : 4000 mg/d]
# Selenium: 55 μg/d [TUL : 400 μg/d]
# Zinc: 11 mg/d [TUL : 40 mg/d]
# Potassium: 3400 mg/d [TUL : Data not found]
# Sodium: 1500 mg/d [TUL : Data not found]
# Chloride: 2 g/d [TUL : 3.6 g/d]
# Vitamin A: 900 μg/d [TUL : 3000 μg/d]
# Vitamin C: 90 mg/d [TUL : 2000 mg/d]
# Vitamin D: 15 μg/d [TUL : 100 μg/d]
# Vitamin E: 15 mg/d [TUL : 1000 mg/d]
# Vitamin K: 120 μg/d [TUL : Data not found]
# Thiamin: 1.2 mg/d [TUL : Data not found]
# Riboflavin: 1.3 mg/d [TUL : Data not found]
# Niacin: 16 mg/d [TUL : 35 mg/d]
# Vitamin B6: 1.7 mg/d [TUL : 100 mg/d]
# Folate: 400 μg/d [TUL : 1000 μg/d]
# Vitamin B12: 2.4 μg/d [TUL : Data not found]
# Pantothenic Acid: 5 mg/d [TUL : Data not found]
# Biotin: 30 μg/d [TUL : Data not found]
# Choline: 550 mg/d [TUL : 3500 mg/d]
# Total Water: 3.7 L/d [TUL : Data not found]
# Carbohydrate: 130 g/d [TUL : Data not found]
# Total Fiber: 30 g/d [TUL : Data not found]
# Linoleic Acid: 14 g/d [TUL : Data not found]
# α-Linolenic Acid: 1.6 g/d [TUL : Data not found]
# Protein: 56 g/d [TUL : Data not found]

# %%
from langchain.memory import ConversationSummaryBufferMemory
from langchain.chains import ConversationalRetrievalChain, LLMChain, StuffDocumentsChain
from langchain.prompts import ChatPromptTemplate, PromptTemplate
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from langchain_huggingface import HuggingFacePipeline
from langchain_core.runnables import RunnablePassthrough, RunnableLambda



medical_prompt = ChatPromptTemplate.from_template(
"""
You are a trusted medical nutrition advisor AI. Your task is to adjust the baseline nutrient intake values for a user based on their medical conditions, medications, and physical activity level.

--- Baseline Nutritional Values ---
{baseline_values}

--- User Profile ---
• Health Conditions: {conditions}
• Activity Level: {activity_level}
• Medications: {medications}

--- Instructions ---
1. For each nutrient:
   - Modify the baseline value if it's medically warranted by any of the user's conditions, medications, or activity level.
   - Justify each change with clinical reasoning and cite whether it's condition-driven, medication-related, or activity-based.

2. In cases where **multiple conditions have conflicting nutrient recommendations** (e.g., Condition X increases need for Nutrient A, while Condition Y requires lowering Nutrient A):
   - **Acknowledge the conflict explicitly.**
   - Suggest a medically reasonable compromise or prioritize based on risk (e.g., "due to higher risk of toxicity in Condition Y, we will lean toward the lower bound").
   - Flag nutrients where close monitoring is essential.

3. If any adjusted value exceeds the Tolerable Upper Limit (TUL), clearly **flag this as a clinical risk** and explain why it might still be justified (or not).

4. Do NOT adjust nutrients that have no medical justification.

--- Output Format ---
Return the final adjusted nutrient values as a structured list or table. Include:
- Nutrient name
- Adjusted value
- Reason for adjustment
- Risk flags (if any)

Be clear, concise, and medically sound.
"""
)
